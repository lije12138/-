# %%
from shezhenv3coco_label_processor import process_labels_to_csv

# %%
data_folder_test = "G:\Dataset\shezhenv3-coco\shezhenv3-coco/test"
file_prefix_test = 'test'
data_folder_val = "G:\Dataset\shezhenv3-coco\shezhenv3-coco/val"
file_prefix_val = 'val'
data_folder_train = "G:\Dataset\shezhenv3-coco\shezhenv3-coco/train"
file_prefix_train = 'train'

process_labels_to_csv(data_folder_test, file_prefix_test)
process_labels_to_csv(data_folder_val, file_prefix_val)
process_labels_to_csv(data_folder_train, file_prefix_train)
# Out:
# 处理完成，结果已保存至: output\test-labels.csv
# 处理完成，结果已保存至: output\val-labels.csv
# 处理完成，结果已保存至: output\train-labels.csv
